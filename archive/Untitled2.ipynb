# %%
preds = []
import numpy as np
import datetime as dt
for _ in range(10):

    preds.append(
            {
                "location": np.random.rand(),
                "datetime": np.random.rand(),
                "city":'loc',
                "inference_time": dt.datetime.now(),
                "target": -1,
                "prediction": np.random.rand()*100,
                "48_lag": np.random.rand()*101,
                "temp_forecast": np.random.rand(),
                "pressure_forecast": np.random.rand(),
                "humidity_forecast": np.random.rand(),
                "temp": -1,
                "pressure": -1,
                "humidity": -1,
            }
        )

# %%
import pandas as pd

# %%
df = pd.DataFrame(preds)

# %%
df
# Out:
#              48_lag city  datetime  humidity  humidity_forecast  \
# datetime
# 0.556544  64.575925  loc  0.556544        -1           0.255436
# 0.162368  49.624561  loc  0.162368        -1           0.320482
# 0.727763   4.176317  loc  0.727763        -1           0.671408
# 0.674215   2.351507  loc  0.674215        -1           0.542636
# 0.169835  14.330294  loc  0.169835        -1           0.674354
# 0.162410  34.309462  loc  0.162410        -1           0.220773
# 0.928264  94.260034  loc  0.928264        -1           0.313209
# 0.532664  22.839734  loc  0.532664        -1           0.701031
# 0.269022  80.503920  loc  0.269022        -1           0.336726
# 0.464060  25.582325  loc  0.464060        -1           0.386029
#
#                      inference_time  location  prediction  pressure  \
# datetime
# 0.556544 2019-10-22 09:15:16.493742  0.495799   84.099042        -1
# 0.162368 2019-10-22 09:15:16.493758  0.984656   94.690147        -1
# ...

# %%
str(pd.Timestamp.now().date())
# Out:
# '2019-10-22'

# %%
def add_stuf(lst,*arg):
    lst.append('ehloe')
add_stuf(lst)

# %%
f"{*('a','b','c')}"
# Out:
#   File "<ipython-input-27-5eb6a7380c5c>", line 4
# SyntaxError: can't use starred expression here
